# %%
import requests
head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'}
res = requests.get("https://buy.yungching.com.tw/region/%E5%8F%B0%E4%B8%AD%E5%B8%82-_c/", headers = head)
print(res.text)
# Out:
# <!DOCTYPE HTML>
# <!--[if lte IE 8]>    <html class="no-js lt-ie9" lang="zh-Hant-TW" > <![endif]-->
# <!--[if gt IE 8]><!-->
# <html dir="ltr" lang="zh-Hant-TW" itemscope itemtype="http://schema.org" >
# <!--<![endif]-->
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" >
#     <meta charset="UTF-8">
#     <title>台中市買屋、購屋、買房子、找房屋 | 永慶房仲網買屋</title>
#
#     <meta name="description" content="買屋、購屋、買房子、找房屋首選永慶房仲網，網羅 台中市-  新成屋、中古屋、社區、住宅等房屋仲介資訊，還有線上影音看屋、成交行情，讓買屋更輕鬆。" />
#     <meta property="fb:app_id" content="320559141361882" />
#     <meta property="og:locale" content="zh_TW" />
#     <meta property="og:title" itemprop="name" content="台中市買屋、購屋、買房子、找房屋 | 永慶房仲網買屋" />
#     <meta property="og:description" content="買屋、購屋、買房子、找房屋首選永慶房仲網，網羅 台中市-  新成屋、中古屋、社區、住宅等房屋仲介資訊，還有線上影音看屋、成交行情，讓買屋更輕鬆。" />
#     <meta property="og:url" itemprop="url" content="https://buy.yungching.com.tw/region/台中市-_c" />
# ...
