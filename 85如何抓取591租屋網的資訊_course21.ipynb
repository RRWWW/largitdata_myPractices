# %%
import requests
import re
import json
res = requests.get('https://rent.591.com.tw/index.php?module=search&action=rslist&is_new_list=1&type=1&searchtype=1&region=8&section=102&kind=1&rentprice=0&listview=img&firstRow=20&totalRows=192')
data = json.loads(res.text)
#print(data)
#print(data.keys())
print(data['main'])
# Out:
# <div class="shList  " >
#     <ul class="shInfo"   >
#         <li class="info">
#             <div class="left" data-bind="4880713" data-img-length="7">
#                 <a href="rent-detail-4880713.html" class="imgbd" target="_blank" title="★秒殺！只有一間！樓中樓★陽台☆"   ><img src="https://cp2.591.com.tw/house/active/2017/02/10/148673400619742500_128x92.jpg" width="128" height="92" alt="★秒殺！只有一間！樓中樓★陽台☆" /></a>
#                 <!-- 更多圖片 -->
#                 <div class="imgMore"><a href="rent-detail-4880713.html" target="_blank">7張照片</a></div>
#             </div>
#             <div class="right">
#                 <p class="title"><a href="rent-detail-4880713.html" target="_blank" class="house_url" title="★秒殺！只有一間！樓中樓★陽台☆"><strong>★秒殺！只有一間！樓中樓★陽台☆</strong></a><img src="./images/index/userCenter/list_vip_v1.png"  border="0" align="absmiddle" class="vipimg" alt="VIP物件" title="VIP物件"/></p>
#                 <p>永興街　台中市-北區&nbsp;崇德路一段</p>
# ...
